# %% [markdown]
# <a href="https://www.bigdatauniversity.com"><img src="https://ibm.box.com/shared/static/cw2c7r3o20w9zn8gkecaeyjhgw3xdgbj.png" width="400" align="center"></a>
#
# <h1 align="center"><font size="5">Data Science Capstone project</font></h1>

# %% [markdown]
# In this notebook I will be building the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# The project is integrated with [github repo.](https://github.com/krishnatejaperannagari/Coursera_Capstone)

# %% [markdown]
# ### Guidelines for dreating dataframe :

# %% [markdown]
# The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
#
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
#
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.
#
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.
#
# Clean your Notebook and add Markdown cells to explain your work and any assumptions you are making.
#
# In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
import urllib.request

wiki_page = urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

parse_tree = BeautifulSoup(wiki_page, "lxml")

table= parse_tree.find("table", style="width:100%; border-collapse:collapse; border:1px solid #ccc;")

# %%
loc_df = pd.DataFrame(columns=['PostalCode', 'Borough', 'Neighborhood'])

i=0

for row in table.findAll('tr'):
    cells = row.findAll('td')
    for cell in cells:
        
        PostalCode = cell.find('b').find(text=True)    
        links = cell.findAll('a')
        if len(links)>0 and links[0].find(text=True) is not None:
            Borough = links[0].find(text=True)
            Neighbourhood = ', '.join(map(str, [neigh.find(text=True) for neigh in links[1:len(links)]]))
            if Neighbourhood =='':
                Neighbourhood = Borough
            loc_df.loc[i] = [PostalCode, Borough, Neighbourhood]
            i+=1
            
loc_df.sort_values(["PostalCode"], axis=0, ascending=True, inplace=True)

loc_df
# Out:
#     PostalCode              Borough  \
# 6          M1B          Scarborough
# 12         M1C          Scarborough
# 18         M1E          Scarborough
# 22         M1G          Scarborough
# 26         M1H          Scarborough
# 32         M1J          Scarborough
# 38         M1K          Scarborough
# 44         M1L          Scarborough
# 51         M1M          Scarborough
# 57         M1N          Scarborough
# 63         M1P          Scarborough
# 69         M1R          Scarborough
# 76         M1S          Scarborough
# 80         M1T          Scarborough
# 83         M1V          Scarborough
# 88         M1W          Scarborough
# 93         M1X          Scarborough
# 27         M2H           North York
# 33         M2J           North York
# 39         M2K           North York
# 45         M2L           North York
# 52         M2M           North York
# 58         M2N           North York
# 64         M2P           North York
# 70         M2R           North York
# 0          M3A           North York
# 7          M3B           North York
# 13         M3C           North York
# 28         M3H           North York
# 34         M3J           North York
# ..         ...                  ...
# 16         M6C                 York
# 21         M6E                 York
# 25         M6G     Downtown Toronto
# 31         M6H             Dufferin
# 37         M6J      Little Portugal
# 43         M6K             Brockton
# 49         M6L           North York
# 55         M6M                 York
# 61         M6N                 York
# 67         M6P            High Park
# 73         M6R             Parkdale
# 79         M6S            Runnymede
# 4          M7A         Queen's Park
# 74         M7R          Mississauga
# 98         M7Y  Business reply mail
# 86         M8V            Etobicoke
# 91         M8W            Etobicoke
# 96         M8X            Etobicoke
# 99         M8Y            Etobicoke
# 100        M8Z            Etobicoke
# 5          M9A            Etobicoke
# 11         M9B            Etobicoke
# 17         M9C            Etobicoke
# 50         M9L           North York
# 56         M9M           North York
# 62         M9N                 York
# 68         M9P            Etobicoke
# 75         M9R            Etobicoke
# 87         M9V            Etobicoke
# 92         M9W            Etobicoke
#
#                                           Neighborhood
# 6                                       Malvern, Rouge
# 12              Rouge Hill, Port Union, Highland Creek
# 18                   Guildwood, Morningside, West Hill
# 22                                              Woburn
# 26                                           Cedarbrae
# 32                                 Scarborough Village
# 38              Kennedy Park, Ionview, Birchmount Park
# 44                     Golden Mile, Clairlea, Oakridge
# 51          Cliffside, Cliffcrest, Scarborough Village
# 57                              Birch Cliff, Cliffside
# 63   Dorset Park, Wexford Heights, Scarborough Town...
# 69                                   Wexford, Maryvale
# 76                                           Agincourt
# 80                             Tam O'Shanter, Sullivan
# 83      Milliken, Agincourt North, Steeles, L'Amoreaux
# 88                                 Steeles, L'Amoreaux
# 93                                         Upper Rouge
# 27                                   Hillcrest Village
# 33                                          Henry Farm
# 39                                     Bayview Village
# 45                                          York Mills
# 52                                         Newtonbrook
# 58                                          Willowdale
# 64                                          York Mills
# 70                                          Willowdale
# 0                                            Parkwoods
# 7                                            Don Mills
# 13                          Don Mills, Flemingdon Park
# 28           Bathurst Manor, Wilson Heights, Downsview
# 34                     Northwood Park, York University
# ..                                                 ...
# 16                                  Humewood-Cedarvale
# 21                                 Caledonia-Fairbanks
# 25                                    Downtown Toronto
# 31                                  Dovercourt Village
# 37                                             Trinity
# 43                  Parkdale Village, Exhibition Place
# 49                                     Maple Leaf Park
# 55             Mount Dennis, Keelsdale and Silverthorn
# 61                             Runnymede, The Junction
# 67                                        The Junction
# 73                                        Roncesvalles
# 79                                             Swansea
# 4                        Ontario Provincial Government
# 74                                         Mississauga
# 98                                 Business reply mail
# 86                                 New Toronto, Mimico
# 91                              Alderwood, Long Branch
# 96                              The Kingsway, Old Mill
# 99   Old Mill, Sunnylea, Humber Bay, Mimico, The Qu...
# 100                              Mimico, The Queensway
# 5                                     Islington Avenue
# 11   West Deane Park, Princess Gardens, Martin Grov...
# 17                                       Markland Wood
# 50                                       Humber Summit
# 56                                    Humberlea, Emery
# 62                                              Weston
# 68                                           Etobicoke
# 75                                   Kingsview Village
# 87   South Steeles, Silverstone, Jamestown, Mount O...
# 92   Clairville, Humberwood, Woodbine Downs, Rexdal...
#
# [101 rows x 3 columns]

# %%
loc_df.shape
# Out:
# (101, 3)

# %% [markdown]
# In an older version of this course, we were leveraging the Google Maps Geocoding API to get the latitude and the longitude coordinates of each neighborhood. However, recently Google started charging for their API: http://geoawesomeness.com/developers-up-in-arms-over-google-maps-api-insane-price-hike/, so we will use the Geocoder Python package instead: https://geocoder.readthedocs.io/index.html.
#
# The problem with this Package is you have to be persistent sometimes in order to get the geographical coordinates of a given postal code. So you can make a call to get the latitude and longitude coordinates of a given postal code and the result would be None, and then make the call again and you would get the coordinates. So, in order to make sure that you get the coordinates for all of our neighborhoods, you can run a while loop for each postal code.
#
# Given that this package can be very unreliable, in case you are not able to get the geographical coordinates of the neighborhoods using the Geocoder package, here is a link to a csv file that has the geographical coordinates of each postal code: http://cocl.us/Geospatial_data

# %%
geo_data = pd.read_csv('https://cocl.us/Geospatial_data')
geo_data
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# 24          M2R  43.782736 -79.442259
# 25          M3A  43.753259 -79.329656
# 26          M3B  43.745906 -79.352188
# 27          M3C  43.725900 -79.340923
# 28          M3H  43.754328 -79.442259
# 29          M3J  43.767980 -79.487262
# ..          ...        ...        ...
# 73          M6C  43.693781 -79.428191
# 74          M6E  43.689026 -79.453512
# 75          M6G  43.669542 -79.422564
# 76          M6H  43.669005 -79.442259
# 77          M6J  43.647927 -79.419750
# 78          M6K  43.636847 -79.428191
# 79          M6L  43.713756 -79.490074
# 80          M6M  43.691116 -79.476013
# 81          M6N  43.673185 -79.487262
# 82          M6P  43.661608 -79.464763
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
geo_cor_df = pd.DataFrame(columns=['PostalCode', 'Borough', 'Neighborhood', 'Latitude', 'Longitude' ])
for index in loc_df.index:
    coord = geo_data.loc[geo_data['Postal Code'] == loc_df["PostalCode"][index]]
    geo_cor_df.loc[index] = [loc_df["PostalCode"][index], loc_df["Borough"][index], loc_df["Neighborhood"][index], coord.iloc[0][1], coord.iloc[0][2]]
geo_cor_df
# Out:
#     PostalCode              Borough  \
# 6          M1B          Scarborough
# 12         M1C          Scarborough
# 18         M1E          Scarborough
# 22         M1G          Scarborough
# 26         M1H          Scarborough
# 32         M1J          Scarborough
# 38         M1K          Scarborough
# 44         M1L          Scarborough
# 51         M1M          Scarborough
# 57         M1N          Scarborough
# 63         M1P          Scarborough
# 69         M1R          Scarborough
# 76         M1S          Scarborough
# 80         M1T          Scarborough
# 83         M1V          Scarborough
# 88         M1W          Scarborough
# 93         M1X          Scarborough
# 27         M2H           North York
# 33         M2J           North York
# 39         M2K           North York
# 45         M2L           North York
# 52         M2M           North York
# 58         M2N           North York
# 64         M2P           North York
# 70         M2R           North York
# 0          M3A           North York
# 7          M3B           North York
# 13         M3C           North York
# 28         M3H           North York
# 34         M3J           North York
# ..         ...                  ...
# 16         M6C                 York
# 21         M6E                 York
# 25         M6G     Downtown Toronto
# 31         M6H             Dufferin
# 37         M6J      Little Portugal
# 43         M6K             Brockton
# 49         M6L           North York
# 55         M6M                 York
# 61         M6N                 York
# 67         M6P            High Park
# 73         M6R             Parkdale
# 79         M6S            Runnymede
# 4          M7A         Queen's Park
# 74         M7R          Mississauga
# 98         M7Y  Business reply mail
# 86         M8V            Etobicoke
# 91         M8W            Etobicoke
# 96         M8X            Etobicoke
# 99         M8Y            Etobicoke
# 100        M8Z            Etobicoke
# 5          M9A            Etobicoke
# 11         M9B            Etobicoke
# 17         M9C            Etobicoke
# 50         M9L           North York
# 56         M9M           North York
# 62         M9N                 York
# 68         M9P            Etobicoke
# 75         M9R            Etobicoke
# 87         M9V            Etobicoke
# 92         M9W            Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 6                                       Malvern, Rouge  43.806686 -79.194353
# 12              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 22                                              Woburn  43.770992 -79.216917
# 26                                           Cedarbrae  43.773136 -79.239476
# 32                                 Scarborough Village  43.744734 -79.239476
# 38              Kennedy Park, Ionview, Birchmount Park  43.727929 -79.262029
# 44                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 51          Cliffside, Cliffcrest, Scarborough Village  43.716316 -79.239476
# 57                              Birch Cliff, Cliffside  43.692657 -79.264848
# 63   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 69                                   Wexford, Maryvale  43.750072 -79.295849
# 76                                           Agincourt  43.794200 -79.262029
# 80                             Tam O'Shanter, Sullivan  43.781638 -79.304302
# 83      Milliken, Agincourt North, Steeles, L'Amoreaux  43.815252 -79.284577
# 88                                 Steeles, L'Amoreaux  43.799525 -79.318389
# 93                                         Upper Rouge  43.836125 -79.205636
# 27                                   Hillcrest Village  43.803762 -79.363452
# 33                                          Henry Farm  43.778517 -79.346556
# 39                                     Bayview Village  43.786947 -79.385975
# 45                                          York Mills  43.757490 -79.374714
# 52                                         Newtonbrook  43.789053 -79.408493
# 58                                          Willowdale  43.770120 -79.408493
# 64                                          York Mills  43.752758 -79.400049
# 70                                          Willowdale  43.782736 -79.442259
# 0                                            Parkwoods  43.753259 -79.329656
# 7                                            Don Mills  43.745906 -79.352188
# 13                          Don Mills, Flemingdon Park  43.725900 -79.340923
# 28           Bathurst Manor, Wilson Heights, Downsview  43.754328 -79.442259
# 34                     Northwood Park, York University  43.767980 -79.487262
# ..                                                 ...        ...        ...
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 25                                    Downtown Toronto  43.669542 -79.422564
# 31                                  Dovercourt Village  43.669005 -79.442259
# 37                                             Trinity  43.647927 -79.419750
# 43                  Parkdale Village, Exhibition Place  43.636847 -79.428191
# 49                                     Maple Leaf Park  43.713756 -79.490074
# 55             Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 61                             Runnymede, The Junction  43.673185 -79.487262
# 67                                        The Junction  43.661608 -79.464763
# 73                                        Roncesvalles  43.648960 -79.456325
# 79                                             Swansea  43.651571 -79.484450
# 4                        Ontario Provincial Government  43.662301 -79.389494
# 74                                         Mississauga  43.636966 -79.615819
# 98                                 Business reply mail  43.662744 -79.321558
# 86                                 New Toronto, Mimico  43.605647 -79.501321
# 91                              Alderwood, Long Branch  43.602414 -79.543484
# 96                              The Kingsway, Old Mill  43.653654 -79.506944
# 99   Old Mill, Sunnylea, Humber Bay, Mimico, The Qu...  43.636258 -79.498509
# 100                              Mimico, The Queensway  43.628841 -79.520999
# 5                                     Islington Avenue  43.667856 -79.532242
# 11   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 17                                       Markland Wood  43.643515 -79.577201
# 50                                       Humber Summit  43.756303 -79.565963
# 56                                    Humberlea, Emery  43.724766 -79.532242
# 62                                              Weston  43.706876 -79.518188
# 68                                           Etobicoke  43.696319 -79.532242
# 75                                   Kingsview Village  43.688905 -79.554724
# 87   South Steeles, Silverstone, Jamestown, Mount O...  43.739416 -79.588437
# 92   Clairville, Humberwood, Woodbine Downs, Rexdal...  43.706748 -79.594054
#
# [101 rows x 5 columns]
