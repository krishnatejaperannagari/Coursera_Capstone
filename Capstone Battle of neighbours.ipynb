# %% [markdown]
# ### Installing and Importing necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

#import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

from opencage.geocoder import OpenCageGeocode
from time import sleep
import traceback

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Define API credentials and version (Content hidden because of sensitive content)

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ### Getting educational institution details in San Fransisco from [web](https://data.sfgov.org/api/views/6adp-a5yv/rows.csv?accessType=DOWNLOAD).

# %%
edu_df = pd.read_csv('https://data.sfgov.org/api/views/6adp-a5yv/rows.csv?accessType=DOWNLOAD')
edu_df.head()
# Out:
#                                             the_geom  \
# 0  MULTIPOLYGON (((-122.41422959861103 37.7811707...
# 1  MULTIPOLYGON (((-122.41529196158669 37.7812009...
# 2  MULTIPOLYGON (((-122.41701008790089 37.7813667...
# 3  MULTIPOLYGON (((-122.41054924969892 37.8078130...
# 4  MULTIPOLYGON (((-122.41521002465295 37.8034172...
#
#                                          institutio  campus  \
# 0  University of California Hastings College of Law  <Null>
# 1  University of California Hastings College of Law  <Null>
# 2  University of California Hastings College of Law  <Null>
# 3                         Academy of Art University     NaN
# 4                         Academy of Art University     NaN
#
#              address          webaddress       phone    st_area_sh  st_length_
# 0  100 McAllister St  www.uchastings.edu  4155654600  13049.073407  492.593768
# 1  198 McAllister St  www.uchastings.edu  4155654600  22642.056685  604.439178
# 2      376 Larkin St  www.uchastings.edu  4155654600  25762.162205  650.066091
# 3   2300 Stockton St                 NaN           0  37469.166147  821.907182
# 4    701 Chestnut St                 NaN           0  10364.131930  432.953369

# %% [markdown]
# ### Removing unnecessary columns from edu_df and adding new columns for cordinates

# %%
edu_df.drop(['the_geom', 'campus', 'webaddress', 'phone', 'st_area_sh', 'st_length_'], axis=1, inplace=True)
edu_df.rename(columns = {"institutio": "Institution", "address":"Address",}, inplace=True)

edu_df['Latitude'] = np.nan
edu_df['Longitude'] = np.nan
edu_df.head()
# Out:
#                                         Institution            Address  \
# 0  University of California Hastings College of Law  100 McAllister St
# 1  University of California Hastings College of Law  198 McAllister St
# 2  University of California Hastings College of Law      376 Larkin St
# 3                         Academy of Art University   2300 Stockton St
# 4                         Academy of Art University    701 Chestnut St
#
#    Latitude  Longitude
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN

# %% [markdown]
# ### Get the latitude and longitude location of the education institution addresses

# %%
for index in edu_df.index:
    location =  geocoder.geocode(edu_df.at[index, 'Address'] + ', San Francisco, CA, United States of America')
    if len(location)>0:
        edu_df.at[index, 'Latitude'] = location[0]['geometry']['lat']
        edu_df.at[index, 'Longitude'] = location[0]['geometry']['lng']
    sleep(1)

print("Coordinates Obtained")
# Out:
# Coordinates Obtained

# %%
edu_df.head()
# Out:
#                                         Institution            Address  \
# 0  University of California Hastings College of Law  100 McAllister St
# 1  University of California Hastings College of Law  198 McAllister St
# 2  University of California Hastings College of Law      376 Larkin St
# 3                         Academy of Art University   2300 Stockton St
# 4                         Academy of Art University    701 Chestnut St
#
#     Latitude   Longitude
# 0  37.780989 -122.413846
# 1  37.781438 -122.415239
# 2  37.781173 -122.416986
# 3  37.807098 -122.410420
# 4  37.803313 -122.415063

# %% [markdown]
# ### Function to get nearby venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        
        sleep(1)
        
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng,
            v['venue']['id'],
            v['venue']['name'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue id',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### Getting list of all venues near the educational institutions

# %%
edu_venues = getNearbyVenues(names=edu_df['Address'],
                                   latitudes=edu_df['Latitude'],
                                   longitudes=edu_df['Longitude']
                                  )

print(edu_venues.shape)
# Out:
# (3421, 8)

# %% [markdown]
# ### Transforming venue data

# %%
print("Removing duplicates \n")

edu_venues.drop_duplicates(['Venue id'], keep='first', inplace=True)

print(edu_venues.shape)
# Out:
# Removing duplicates
#
# (1876, 8)

# %%
edu_venues.head()
# Out:
#         Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  100 McAllister St              37.780989             -122.413846
# 1  100 McAllister St              37.780989             -122.413846
# 2  100 McAllister St              37.780989             -122.413846
# 3  100 McAllister St              37.780989             -122.413846
# 4  100 McAllister St              37.780989             -122.413846
#
#                    Venue id                           Venue  Venue Latitude  \
# 0  4f5d49a5e4b0695cbbe24694                      The Strand       37.779888
# 1  46d36f99f964a520594a1fe3                 Orpheum Theatre       37.779315
# 2  4a73812ff964a520a0dc1fe3  Alonzo King LINES Dance Center       37.780116
# 3  59b759e1646e387b4245f12a                          Villon       37.780865
# 4  55da2db5498eb79ab95580cb               George and Lennie       37.781701
#
#    Venue Longitude     Venue Category
# 0      -122.413138            Theater
# 1      -122.414790            Theater
# 2      -122.412187       Dance Studio
# 3      -122.412471  French Restaurant
# 4      -122.415213        Coffee Shop

# %%
print("Dataset Count")
edu_venues['Venue Category'].value_counts().head(50)
# Out:
# Dataset Count
# Coffee Shop                 102
# Café                         67
# Sandwich Place               41
# Bar                          40
# Cocktail Bar                 34
# Mexican Restaurant           33
# Hotel                        33
# Food Truck                   32
# Park                         31
# Italian Restaurant           30
# Sushi Restaurant             30
# American Restaurant          30
# Pizza Place                  29
# Vietnamese Restaurant        27
# Bakery                       26
# Gym                          26
# Gym / Fitness Center         26
# Clothing Store               25
# New American Restaurant      24
# Art Gallery                  23
# Thai Restaurant              23
# Wine Bar                     22
# Deli / Bodega                21
# Cosmetics Shop               20
# Seafood Restaurant           18
# Burger Joint                 18
# Breakfast Spot               18
# Chinese Restaurant           17
# Boutique                     17
# Spa                          16
# Yoga Studio                  16
# Furniture / Home Store       15
# Ice Cream Shop               15
# Japanese Restaurant          14
# Diner                        14
# French Restaurant            14
# Theater                      14
# Liquor Store                 12
# Mediterranean Restaurant     12
# Wine Shop                    12
# Restaurant                   12
# Salad Place                  12
# Grocery Store                11
# Bookstore                    11
# Men's Store                  11
# Bubble Tea Shop              11
# Juice Bar                    11
# Indian Restaurant            11
# Optical Shop                 10
# Dive Bar                     10
# Name: Venue Category, dtype: int64

# %%
print('There are {} uniques categories.'.format(len(edu_venues['Venue Category'].unique())))
# Out:
# There are 309 uniques categories.

# %% [markdown]
# ### Analyzing the restaurants in the location

# %%
res_data = edu_venues[edu_venues['Venue Category'].str.contains('restaurant', case=False)]
print(res_data.shape)
# Out:
# (412, 8)

# %% [markdown]
# ### Getting restaurant characteristics

# %%
def getRestaurantDetails(names, vid):
    
    restaurant_list=[]
    
    
    for name, res_id in zip(names, vid):
       
        sleep(1)
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(
            res_id, CLIENT_ID, CLIENT_SECRET, VERSION)
        
        # make the GET request
        try:
            result = requests.get(url).json()['response']['venue']
        except Exception:
            print(url)
            traceback.print_exc()
            continue
        
        res_pricetier = None
        res_reservations = None
        res_outdoor = None
        res_wifi = None
        res_delivery = None
        res_music = None
        res_rroom = None
        res_proom = None
        res_wheelchair = None
        res_parking = None
        
        for group in result['attributes']['groups']:
            try:
                if group['type'].lower() == 'price':
                    res_pricetier = group['items'][0]['priceTier']
                    continue
            except:
                pass
            
            try:
                if group['type'].lower() == 'reservations':
                    res_reservations = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'outdoorSeating':
                    res_outdoor = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'wifi':
                    res_wifi = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'diningoptions':
                    res_delivery = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'music':
                    res_music = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'restroom':
                    res_rroom = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'privateroom':
                    res_proom = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'wheelchairaccessible':
                    res_wheelchair = group['items'][0]['displayValue']
                    continue
            except:
                pass
            try:
                if group['type'].lower() == 'parking':
                    if 'no' in group['summary'].lower():
                        res_parking = 'Not Avaliable'
                    else:
                        res_parking = 'Available'
                        
                    continue
            except:
                pass

        # return only relevant information for each nearby venue
        try:
            restaurant_list.append([
                name,  
                result['name'],
                result['id'],  
                result['categories'][0]['name'],
                result['likes']['count'],
                result['photos']['count'],
                result['rating'],
                result['tips']['count'],
                res_pricetier,
                res_reservations,
                res_outdoor,
                res_wifi,
                res_delivery,
                res_music,
                res_rroom,
                res_proom,
                res_wheelchair,
                res_parking])
        except:
            print(url)
            traceback.print_exc()
            continue
            
    nearby_venues = pd.DataFrame([item for item in restaurant_list])

    nearby_venues.columns = ['Neighborhood', 
            'Venue',
            'Venue id',
            'Venue Category',
            'Venue Likes',
            'Venue photos count',
            'Venue rating', 
            'Venue Tips',
            'Price Tier',
            'Reservations',
            'Outdoor',
            'Wifi',
            'Delivery',
            'Music',
            'Rest room',
            'Private room',
            'Wheel chair',
            'Parking']
        
    return(nearby_venues)

# %%
res_venues = getRestaurantDetails(names=res_data['Neighborhood'],
                             vid=res_data['Venue id']
                                  )

res_venues.shape
# Out:
# (403, 18)

# %%
res_venues.head()
# Out:
#         Neighborhood                 Venue                  Venue id  \
# 0  100 McAllister St                Villon  59b759e1646e387b4245f12a
# 1  100 McAllister St    The Flying Falafel  54c42de4498ee52a43a5ee44
# 2  100 McAllister St  Morty's Delicatessen  49d66c4ef964a520c95c1fe3
# 3  100 McAllister St      Golden Era Vegan  547a3a09498edded45384099
# 4  100 McAllister St         Yemen Kitchen  5633e4a5498e430fc92b4b53
#
#                   Venue Category  Venue Likes  Venue photos count  \
# 0              French Restaurant          119                 135
# 1       Mediterranean Restaurant          271                 132
# 2            American Restaurant           36                  39
# 3  Vegetarian / Vegan Restaurant           96                 102
# 4      Middle Eastern Restaurant           28                  39
#
#    Venue rating  Venue Tips  Price Tier Reservations  Outdoor Wifi  Delivery  \
# 0           8.8          14         3.0          NaN      NaN  NaN  Delivery
# 1           8.7          58         2.0           No      NaN  NaN  Delivery
# 2           8.1          31         1.0           No      NaN  NaN  Delivery
# 3           8.3          28         2.0          NaN      NaN  NaN       NaN
# 4           8.3           9         2.0           No      NaN  NaN  Take-out
#
#   Music Rest room Private room Wheel chair    Parking
# 0   NaN       NaN          NaN         NaN  Available
# 1   NaN       NaN          NaN         NaN        NaN
# 2   NaN       NaN          NaN         NaN        NaN
# 3   NaN       NaN          NaN         NaN        NaN
# 4   NaN       NaN          NaN         NaN        NaN

# %%
# Replacing all the Nan values to No Data Available
res_venues.fillna(value = "No Data Available", inplace = True)

#joining with edu_df 
res_venues = res_venues.join(edu_df.set_index('Address'), on='Neighborhood')

res_venues.head()
# Out:
#         Neighborhood                 Venue                  Venue id  \
# 0  100 McAllister St                Villon  59b759e1646e387b4245f12a
# 1  100 McAllister St    The Flying Falafel  54c42de4498ee52a43a5ee44
# 2  100 McAllister St  Morty's Delicatessen  49d66c4ef964a520c95c1fe3
# 3  100 McAllister St      Golden Era Vegan  547a3a09498edded45384099
# 4  100 McAllister St         Yemen Kitchen  5633e4a5498e430fc92b4b53
#
#                   Venue Category  Venue Likes  Venue photos count  \
# 0              French Restaurant          119                 135
# 1       Mediterranean Restaurant          271                 132
# 2            American Restaurant           36                  39
# 3  Vegetarian / Vegan Restaurant           96                 102
# 4      Middle Eastern Restaurant           28                  39
#
#    Venue rating  Venue Tips Price Tier       Reservations            Outdoor  \
# 0           8.8          14          3  No Data Available  No Data Available
# 1           8.7          58          2                 No  No Data Available
# 2           8.1          31          1                 No  No Data Available
# 3           8.3          28          2  No Data Available  No Data Available
# 4           8.3           9          2                 No  No Data Available
#
#                 Wifi           Delivery              Music          Rest room  \
# 0  No Data Available           Delivery  No Data Available  No Data Available
# 1  No Data Available           Delivery  No Data Available  No Data Available
# 2  No Data Available           Delivery  No Data Available  No Data Available
# 3  No Data Available  No Data Available  No Data Available  No Data Available
# 4  No Data Available           Take-out  No Data Available  No Data Available
#
#         Private room        Wheel chair            Parking  \
# 0  No Data Available  No Data Available          Available
# 1  No Data Available  No Data Available  No Data Available
# 2  No Data Available  No Data Available  No Data Available
# 3  No Data Available  No Data Available  No Data Available
# 4  No Data Available  No Data Available  No Data Available
#
#                                         Institution   Latitude   Longitude
# 0  University of California Hastings College of Law  37.780989 -122.413846
# 1  University of California Hastings College of Law  37.780989 -122.413846
# 2  University of California Hastings College of Law  37.780989 -122.413846
# 3  University of California Hastings College of Law  37.780989 -122.413846
# 4  University of California Hastings College of Law  37.780989 -122.413846

# %%
res_venues['Venue Category'].value_counts().head(15)
# Out:
# American Restaurant         30
# Italian Restaurant          30
# Mexican Restaurant          30
# Sushi Restaurant            29
# Vietnamese Restaurant       27
# Thai Restaurant             23
# New American Restaurant     23
# Seafood Restaurant          18
# Chinese Restaurant          16
# Japanese Restaurant         14
# French Restaurant           13
# Restaurant                  12
# Mediterranean Restaurant    12
# Indian Restaurant           11
# Korean Restaurant            8
# Name: Venue Category, dtype: int64

# %% [markdown]
# ### Transforming the dataframe

# %%
trans_res_venues = res_venues.copy()

#Dropping unnecessary columns
trans_res_venues.drop(['Neighborhood', 'Venue', 'Venue id', 'Venue Likes', 'Venue photos count', 'Venue rating', 'Venue Tips', 'Latitude', 'Longitude'], axis=1,inplace = True)

trans_res_venues.shape
# Out:
# (403, 12)

# %%
trans_res_venues.head()
# Out:
#                   Venue Category Price Tier       Reservations  \
# 0              French Restaurant          3  No Data Available
# 1       Mediterranean Restaurant          2                 No
# 2            American Restaurant          1                 No
# 3  Vegetarian / Vegan Restaurant          2  No Data Available
# 4      Middle Eastern Restaurant          2                 No
#
#              Outdoor               Wifi           Delivery              Music  \
# 0  No Data Available  No Data Available           Delivery  No Data Available
# 1  No Data Available  No Data Available           Delivery  No Data Available
# 2  No Data Available  No Data Available           Delivery  No Data Available
# 3  No Data Available  No Data Available  No Data Available  No Data Available
# 4  No Data Available  No Data Available           Take-out  No Data Available
#
#            Rest room       Private room        Wheel chair            Parking  \
# 0  No Data Available  No Data Available  No Data Available          Available
# 1  No Data Available  No Data Available  No Data Available  No Data Available
# 2  No Data Available  No Data Available  No Data Available  No Data Available
# 3  No Data Available  No Data Available  No Data Available  No Data Available
# 4  No Data Available  No Data Available  No Data Available  No Data Available
#
#                                         Institution
# 0  University of California Hastings College of Law
# 1  University of California Hastings College of Law
# 2  University of California Hastings College of Law
# 3  University of California Hastings College of Law
# 4  University of California Hastings College of Law

# %% [markdown]
# ### Coding the categorical variables

# %%
#Encoding the categorical variables
trans_res_venues = trans_res_venues.apply(LabelEncoder().fit_transform)

trans_res_venues
# Out:
#      Venue Category  Price Tier  Reservations  Outdoor  Wifi  Delivery  Music  \
# 0                18           2             1        0     2         1      3
# 1                34           1             0        0     2         1      3
# 2                 1           0             0        0     2         1      3
# 3                61           1             1        0     2         2      3
# 4                36           1             0        0     2         5      3
# 5                45           1             2        0     1         3      4
# 6                62           0             1        0     2         5      3
# 7                 3           1             0        0     2         1      3
# 8                62           1             1        0     2         1      3
# 9                54           1             0        0     2         1      3
# 10               45           1             1        0     2         2      3
# 11               61           0             1        0     2         1      3
# 12               15           1             0        0     2         1      3
# 13               52           1             0        0     2         5      3
# 14               62           0             1        0     2         3      3
# 15               34           1             0        0     2         1      3
# 16               57           2             1        0     2         1      3
# 17               62           1             1        0     2         1      3
# 18                1           1             0        0     3         3      3
# 19               62           0             2        0     2         5      3
# 20               35           0             0        0     2         1      3
# 21               51           4             1        0     2         1      3
# 22                8           0             2        0     2         5      3
# 23               62           0             1        0     2         3      2
# 24               62           1             1        0     2         3      3
# 25               31           0             0        0     2         5      3
# 26               35           0             0        0     2         3      3
# 27               25           1             1        0     2         1      3
# 28               45           1             1        0     2         2      3
# 29               58           1             1        0     2         0      3
# 30                1           1             1        0     2         1      3
# 31               56           4             1        0     2         1      3
# 32                3           1             1        0     2         1      3
# 33               62           0             0        0     2         3      3
# 34               58           1             2        0     2         1      3
# 35               62           1             1        0     2         1      3
# 36               58           1             1        0     2         1      3
# 37               52           1             2        0     2         1      3
# 38               25           2             1        0     2         1      3
# 39               31           1             2        0     2         1      3
# 40               25           0             0        0     2         5      3
# 41               58           0             0        0     2         1      3
# 42               58           1             1        0     2         1      3
# 43               61           1             1        0     2         1      3
# 44               54           1             1        0     2         4      3
# 45               45           1             1        0     2         1      3
# 46               48           2             1        0     0         3      3
# 47               48           2             1        0     2         1      3
# 48                1           2             1        0     0         3      1
# 49               48           1             1        0     0         3      4
# 50               45           0             0        0     1         1      3
# 51               48           1             2        0     3         3      3
# 52               35           0             1        0     2         1      3
# 53                1           3             2        0     2         1      1
# 54               26           3             1        0     2         3      3
# 55                1           1             1        0     3         1      3
# 56               48           2             1        0     3         1      3
# 57               48           0             0        0     3         1      3
# 58               26           2             2        0     2         1      3
# 59               48           3             1        0     2         2      3
# 60                8           0             0        0     2         1      3
# 61               54           1             1        0     2         2      3
# 62               48           2             1        0     2         2      3
# 63               26           1             1        0     2         2      3
# 64               60           2             1        0     2         1      3
# 65               25           1             0        0     2         5      3
# 66               26           1             0        0     2         1      3
# 67                5           1             0        0     2         1      2
# 68               31           1             1        0     2         4      3
# 69               54           1             2        0     2         5      3
# 70                8           0             1        0     3         2      3
# 71               26           3             1        0     2         3      3
# 72               62           1             2        0     0         5      3
# 73               48           2             0        0     2         5      3
# 74               34           1             2        0     2         1      4
# 75               39           3             1        0     2         1      3
# 76                0           1             2        0     2         1      3
# 77               62           0             1        0     2         3      2
# 78               37           4             2        0     2         1      3
# 79               62           2             2        0     2         3      3
# 80                1           1             2        0     2         1      3
# 81               54           1             1        0     2         2      3
# 82               26           1             1        0     2         1      3
# 83               58           1             1        0     2         1      3
# 84               45           1             2        0     3         3      3
# 85               54           1             0        0     2         1      3
# 86                1           1             1        0     2         1      3
# 87                8           1             1        0     2         2      3
# 88                8           1             1        0     2         5      3
# 89               58           1             1        0     2         5      3
# 90               55           3             1        0     2         3      3
# 91               31           1             2        0     2         1      3
# 92               54           0             0        0     2         1      3
# 93               39           2             0        0     2         1      3
# 94               26           1             1        0     2         1      3
# 95               54           1             0        0     2         1      1
# 96               62           2             1        0     2         1      1
# 97                1           3             1        0     2         1      1
# 98               31           0             0        0     2         3      3
# 99               21           2             2        0     2         3      3
# 100              28           1             2        0     2         4      3
# 101              54           1             1        0     2         1      3
# 102              35           0             1        0     2         1      3
# 103              17           1             0        0     2         5      3
# 104              58           1             1        0     2         1      3
# 105               1           3             1        0     2         3      3
# 106              23           4             2        0     2         3      3
# 107              44           1             0        0     2         3      2
# 108              18           2             1        0     2         3      3
# 109               1           1             2        0     3         5      3
# 110              18           3             1        0     2         3      3
# 111               4           1             0        0     2         1      3
# 112              26           2             1        0     3         1      3
# 113              26           1             1        0     2         1      3
# 114              62           1             2        0     2         1      3
# 115               1           1             0        0     0         1      3
# 116              58           1             2        0     3         3      3
# 117              52           2             1        0     2         4      3
# 118              58           0             2        0     2         1      1
# 119              25           1             1        0     2         2      3
# 120               3           2             1        0     3         1      3
# 121              54           3             1        0     2         1      3
# 122               1           2             1        0     3         1      3
# 123              34           1             0        0     2         1      3
# 124              46           4             0        0     2         1      3
# 125              27           0             0        0     2         5      3
# 126              45           1             2        0     3         1      3
# 127              32           1             2        0     2         1      3
# 128              18           0             0        0     2         1      3
# 129              39           2             0        0     0         1      3
# 130              54           0             0        0     2         1      4
# 131              58           1             1        0     2         5      4
# 132              28           0             0        0     2         1      3
# 133              45           1             0        0     3         3      3
# 134              18           3             1        0     2         3      1
# 135              10           2             1        0     2         3      2
# 136              26           2             1        0     2         3      3
# 137              39           2             1        0     1         1      3
# 138              48           2             1        0     2         1      3
# 139               8           2             2        0     2         4      3
# 140               7           2             2        0     2         4      3
# 141               1           2             1        0     2         1      1
# 142              28           1             2        0     2         1      4
# 143              10           1             0        0     2         1      3
# 144              38           3             1        0     2         1      3
# 145              18           1             1        0     1         1      4
# 146              48           2             1        0     2         1      3
# 147              54           1             0        0     2         1      3
# 148              20           0             0        0     2         1      3
# 149              39           2             1        0     2         4      3
# 150               5           1             1        0     2         2      3
# 151               5           3             1        0     2         3      3
# 152              34           1             2        0     2         4      3
# 153              62           0             1        0     2         1      3
# 154              39           3             1        0     2         4      3
# 155              48           2             1        0     2         2      3
# 156              58           1             1        0     2         1      3
# 157              26           2             1        0     2         1      3
# 158              54           1             0        0     2         1      3
# 159              42           2             1        0     2         1      3
# 160              29           1             0        0     2         3      3
# 161              35           1             2        0     2         3      3
# 162              25           1             1        0     0         3      4
# 163              39           0             2        0     2         1      3
# 164              34           1             1        0     2         1      3
# 165              35           1             0        0     2         3      3
# 166              31           1             0        0     0         3      3
# 167              54           1             2        0     2         1      3
# 168              39           3             1        0     2         1      3
# 169              28           1             0        0     2         1      3
# 170              34           1             1        0     2         1      3
# 171               1           0             2        0     2         1      3
# 172              58           1             1        0     2         1      3
# 173              58           1             1        0     2         1      3
# 174               1           1             2        0     2         1      3
# 175              26           1             1        0     2         1      3
# 176               8           0             0        0     2         1      3
# 177              62           1             1        0     3         1      3
# 178              62           0             0        0     2         5      2
# 179               6           4             1        0     2         5      3
# 180              28           1             1        0     2         1      3
# 181              39           2             1        0     1         1      3
# 182              39           2             2        0     2         1      3
# 183              39           2             1        0     2         2      4
# 184              17           1             2        0     2         1      2
# 185              35           0             1        0     2         4      3
# 186              40           2             1        0     2         1      3
# 187              14           2             1        0     1         3      3
# 188              62           0             0        0     1         1      3
# 189              31           1             1        0     2         2      3
# 190              28           3             1        0     0         3      3
# 191              44           4             0        0     2         3      3
# 192              39           2             1        0     3         1      3
# 193              54           1             2        0     2         1      3
# 194               8           2             2        0     3         3      3
# 195              36           1             1        0     1         1      3
# 196              12           1             2        0     2         1      3
# 197              61           1             1        0     3         1      3
# 198               1           1             0        0     3         1      3
# 199              58           1             1        0     2         1      3
# 200              15           1             0        0     2         1      3
# 201              33           1             0        0     2         1      3
# 202              35           2             1        0     2         3      3
# 203              44           2             0        0     2         1      3
# 204              39           2             1        0     2         2      3
# 205              39           2             0        0     2         1      3
# 206              54           2             1        0     2         3      3
# 207              39           2             1        0     3         1      3
# 208              45           1             1        0     3         3      3
# 209              58           1             2        0     2         5      3
# 210              18           2             1        0     3         1      3
# 211              18           1             0        0     2         1      3
# 212              18           2             1        0     2         3      3
# 213              26           1             0        0     1         1      3
# 214              35           1             0        0     2         3      3
# 215               1           1             1        0     2         1      3
# 216              26           1             0        0     2         1      3
# 217              25           1             2        0     2         4      3
# 218              62           0             1        0     2         1      3
# 219              47           2             2        0     2         3      3
# 220              35           0             0        0     2         1      3
# 221               6           1             0        0     2         4      3
# 222              54           1             0        0     2         3      2
# 223              57           1             1        0     3         2      3
# 224              54           1             2        0     2         4      3
# 225              28           2             2        0     2         3      3
# 226              19           1             2        0     2         1      3
# 227              22           4             2        0     2         2      4
# 228              54           2             0        0     2         3      3
# 229              45           1             1        0     2         2      3
# 230              44           1             1        0     2         1      3
# 231              35           1             2        0     3         1      3
# 232              43           2             1        0     0         1      4
# 233              54           1             1        0     2         1      3
# 234              54           1             1        0     2         1      3
# 235               5           0             0        0     2         1      3
# 236              35           0             0        0     2         3      3
# 237               2           1             0        0     0         1      3
# 238              48           1             1        0     2         3      3
# 239              11           0             0        0     2         5      3
# 240               1           1             0        0     0         1      2
# 241               1           1             1        0     2         2      3
# 242              44           4             1        0     2         1      3
# 243               1           1             0        0     3         1      3
# 244               8           0             1        0     2         2      3
# 245              16           0             1        0     3         5      3
# 246               1           0             0        0     3         1      3
# 247              62           1             1        0     2         4      4
# 248              44           4             0        0     2         1      3
# 249               6           4             1        0     2         1      3
# 250              58           1             2        0     2         5      4
# 251              26           2             1        0     2         4      4
# 252              26           1             2        0     2         1      3
# 253              58           1             1        0     2         1      3
# 254              18           2             1        0     2         1      1
# 255              10           2             2        0     3         5      3
# 256              28           1             0        0     2         1      2
# 257              34           1             1        0     2         1      3
# 258               1           2             1        0     2         1      3
# 259              28           2             1        0     2         3      3
# 260              48           2             0        0     2         1      3
# 261              26           2             1        0     1         3      3
# 262              61           1             1        0     2         1      2
# 263              10           1             2        0     2         5      3
# 264               1           3             1        0     2         3      3
# 265              26           2             1        0     2         5      4
# 266              34           0             0        0     2         1      3
# 267              18           3             1        0     2         1      3
# 268              28           3             1        0     2         1      3
# 269               1           2             1        0     2         1      3
# 270              39           3             1        0     3         1      3
# 271              58           0             1        0     2         3      3
# 272              19           2             1        0     2         1      3
# 273              35           1             0        0     2         3      3
# 274              18           1             0        0     2         5      3
# 275              43           1             1        0     1         1      3
# 276              62           1             0        0     2         5      3
# 277              54           2             0        0     2         5      3
# 278              34           1             1        0     3         1      3
# 279              39           2             1        0     3         1      3
# 280              48           1             2        0     2         1      3
# 281              35           1             2        0     2         5      3
# 282              45           2             1        0     3         3      4
# 283               2           1             0        0     2         1      3
# 284              49           1             1        0     2         1      3
# 285              60           3             1        0     2         1      3
# 286               3           2             2        0     2         3      3
# 287              26           1             2        0     2         1      3
# 288              42           4             2        0     3         1      3
# 289              26           2             1        0     2         1      3
# 290              32           1             1        0     2         4      3
# 291               8           2             1        0     2         1      3
# 292              18           2             2        0     2         2      3
# 293              26           1             0        0     2         1      3
# 294              35           0             0        0     2         2      3
# 295              26           1             2        0     2         1      3
# 296               8           1             2        0     2         1      3
# 297              26           1             2        0     2         1      1
# 298              26           1             0        0     0         1      3
# 299              34           1             0        0     3         3      3
# 300              26           2             1        0     2         3      4
# 301              54           3             2        0     2         1      2
# 302              39           2             1        0     2         2      3
# 303              39           3             1        0     3         1      3
# 304              28           2             1        0     3         0      1
# 305              39           2             1        0     1         1      1
# 306              45           1             2        0     3         1      3
# 307              36           1             0        0     2         1      3
# 308              20           2             1        0     1         3      0
# 309              56           0             0        0     2         3      3
# 310              62           1             1        0     2         1      3
# 311              44           4             0        0     2         1      3
# 312              54           1             0        0     2         5      3
# 313              26           1             1        0     2         3      3
# 314              61           0             2        0     2         1      3
# 315              56           1             1        0     2         4      3
# 316              30           1             0        0     2         1      3
# 317              25           1             1        0     2         1      3
# 318               1           3             1        0     2         3      3
# 319              62           0             0        0     2         3      3
# 320              28           1             0        0     2         1      3
# 321              26           1             1        0     2         3      3
# 322              48           1             0        0     2         1      3
# 323               8           0             0        0     2         1      3
# 324              62           0             1        0     2         1      3
# 325              56           4             2        0     2         3      3
# 326              13           4             0        0     2         2      3
# 327              35           1             0        0     2         1      3
# 328              53           2             1        0     3         1      3
# 329              43           2             1        0     3         1      3
# 330              62           1             1        0     2         1      3
# 331              28           1             0        0     2         1      3
# 332              35           0             0        0     2         1      3
# 333              48           1             1        0     3         1      3
# 334               1           1             1        0     3         2      3
# 335              41           4             0        0     2         5      2
# 336               3           1             2        0     2         1      3
# 337               1           1             1        0     2         5      3
# 338              62           1             1        0     2         5      3
# 339              58           1             1        0     2         1      3
# 340              54           1             0        0     2         1      3
# 341              58           1             2        0     2         1      3
# 342              35           0             0        0     2         3      3
# 343              28           0             0        0     2         3      3
# 344              35           0             0        0     2         1      3
# 345              35           0             0        0     2         1      3
# 346              39           3             1        0     2         4      2
# 347              54           2             2        0     2         1      3
# 348              36           1             2        0     2         3      3
# 349               3           0             2        0     2         1      3
# 350              58           1             1        0     2         2      3
# 351              35           0             1        0     2         1      3
# 352               8           0             1        0     2         5      3
# 353              21           4             1        0     2         1      3
# 354              26           1             0        0     1         5      2
# 355               9           1             0        0     1         3      3
# 356              39           2             1        0     2         2      3
# 357               2           1             1        0     2         3      3
# 358              32           1             1        0     1         4      2
# 359              17           1             1        0     2         2      3
# 360              25           1             0        0     2         5      3
# 361              59           2             1        0     3         1      3
# 362              32           1             2        0     2         2      3
# 363              35           3             2        0     2         3      2
# 364              35           0             0        0     2         5      3
# 365              26           1             0        0     2         1      3
# 366              25           1             1        0     2         1      3
# 367              35           0             0        0     2         5      3
# 368              50           1             2        0     2         1      1
# 369              35           1             0        0     2         1      3
# 370              25           1             2        0     0         4      2
# 371              35           0             0        0     2         1      1
# 372              50           1             1        0     1         5      3
# 373              24           1             1        0     2         1      3
# 374              15           0             0        0     2         1      3
# 375              32           0             0        0     2         4      3
# 376              35           1             0        0     2         1      3
# 377              35           0             0        0     2         1      3
# 378              26           2             2        0     2         3      3
# 379              35           0             0        0     2         1      3
# 380               0           1             0        0     2         3      3
# 381              32           1             1        0     2         1      3
# 382              52           1             2        0     2         1      1
# 383              52           1             0        0     2         4      3
# 384              11           0             1        0     2         2      3
# 385              34           1             1        0     2         1      3
# 386              39           1             2        0     3         2      3
# 387              16           0             1        0     2         2      3
# 388              48           1             2        0     0         3      3
# 389               1           1             0        0     3         3      3
# 390              54           1             2        0     2         1      3
# 391              36           1             1        0     2         1      3
# 392              35           0             0        0     2         1      3
# 393              54           1             0        0     2         1      3
# 394              54           1             2        0     2         3      3
# 395               1           1             2        0     0         3      3
# 396              58           1             1        0     2         5      3
# 397               3           1             2        0     2         5      3
# 398               8           1             0        0     2         3      3
# 399               8           0             2        0     2         1      3
# 400               8           0             2        0     2         1      3
# 401              31           1             0        0     2         3      3
# 402              62           1             1        0     2         1      2
#
#      Rest room  Private room  Wheel chair  Parking  Institution
# 0            0             0            0        0           15
# 1            0             0            0        1           15
# 2            0             0            0        1           15
# 3            0             0            0        1           15
# 4            0             0            0        1           15
# 5            1             1            0        1           15
# 6            0             0            0        1           15
# 7            0             0            0        1           15
# 8            0             0            0        1           15
# 9            0             0            0        1           15
# 10           0             0            0        1           15
# 11           0             0            0        1           15
# 12           0             0            0        1           15
# 13           0             0            0        1           15
# 14           0             0            0        1           15
# 15           0             0            0        1           15
# 16           0             0            0        1           15
# 17           1             0            0        1           15
# 18           0             0            0        1           15
# 19           0             0            0        1           15
# 20           1             0            1        1           15
# 21           0             0            0        1           15
# 22           0             0            0        1           15
# 23           0             0            1        1           15
# 24           0             0            0        1           15
# 25           1             0            1        1           15
# 26           0             0            0        1           15
# 27           0             0            0        1           15
# 28           0             0            0        1           15
# 29           1             0            0        1           15
# 30           0             0            0        1           15
# 31           0             0            0        1           15
# 32           0             0            0        1           15
# 33           0             0            0        1           15
# 34           0             0            0        1           15
# 35           1             0            0        0           15
# 36           0             0            0        1           15
# 37           0             0            0        1           15
# 38           0             0            0        1           15
# 39           0             0            0        1           15
# 40           0             0            0        1           15
# 41           0             0            0        1           15
# 42           0             0            0        1           15
# 43           0             0            0        1           15
# 44           0             0            0        1           15
# 45           0             0            0        1           15
# 46           0             0            0        1            0
# 47           0             0            0        1            0
# 48           0             0            0        1            0
# 49           0             0            0        1            0
# 50           0             0            0        1            0
# 51           0             0            0        1            0
# 52           0             0            0        1            0
# 53           1             0            1        0            0
# 54           0             0            0        1            0
# 55           0             0            0        1            0
# 56           0             0            0        1            0
# 57           0             0            0        1            0
# 58           0             0            0        1            0
# 59           0             0            0        1            0
# 60           0             0            0        1            0
# 61           0             0            0        1            0
# 62           0             0            0        1            0
# 63           0             0            0        1            0
# 64           0             0            0        1            0
# 65           0             0            0        1            0
# 66           0             0            0        1            0
# 67           0             0            1        0            0
# 68           1             0            0        1            0
# 69           0             0            0        1            0
# 70           0             0            0        1            0
# 71           0             0            0        1            0
# 72           0             0            0        1            0
# 73           0             0            0        1            0
# 74           0             0            0        1            0
# 75           0             0            0        1            0
# 76           0             0            0        1            0
# 77           0             0            0        1            0
# 78           0             0            0        1            0
# 79           0             0            0        1            0
# 80           0             0            0        1            0
# 81           0             0            0        1            0
# 82           0             0            0        1            0
# 83           0             0            0        1            0
# 84           0             0            0        1            0
# 85           0             0            0        1            0
# 86           0             0            0        1            0
# 87           0             0            0        1            0
# 88           0             0            0        1            0
# 89           0             0            0        1            0
# 90           0             0            0        1            0
# 91           0             0            0        1            0
# 92           0             0            0        1            0
# 93           0             0            0        1            0
# 94           0             0            0        1            0
# 95           0             0            0        1            0
# 96           0             0            0        0            0
# 97           1             0            1        0            0
# 98           0             0            0        1            0
# 99           0             0            0        1            0
# 100          0             0            0        1            0
# 101          0             0            0        1            0
# 102          1             0            0        0            0
# 103          0             0            0        1            0
# 104          0             0            0        1            0
# 105          0             0            0        1            0
# 106          0             0            0        1            0
# 107          1             0            0        1            0
# 108          0             0            0        1            0
# 109          0             0            0        1            0
# 110          0             0            0        1            0
# 111          0             0            0        1            0
# 112          0             0            0        1            0
# 113          0             0            0        1            0
# 114          0             0            0        1            0
# 115          0             0            0        1            0
# 116          0             0            0        1            0
# 117          1             0            0        1            0
# 118          0             0            0        1            0
# 119          0             0            0        1            0
# 120          1             1            0        1            0
# 121          1             0            0        1            0
# 122          0             0            0        1            0
# 123          0             0            0        1            0
# 124          0             0            0        1            0
# 125          0             0            0        1            0
# 126          0             0            0        1            0
# 127          0             0            0        1            0
# 128          0             0            0        1            0
# 129          0             0            1        1            0
# 130          0             0            1        0            0
# 131          1             0            1        1            0
# 132          0             0            0        1            0
# 133          0             0            0        1            0
# 134          0             0            0        1            0
# 135          0             0            0        1            0
# 136          0             0            0        1            0
# 137          0             0            1        1            0
# 138          0             0            0        1            0
# 139          0             0            0        1            0
# 140          1             0            0        1            0
# 141          0             0            0        1            0
# 142          0             0            0        1            0
# 143          0             0            0        1            0
# 144          0             0            0        1            0
# 145          0             0            0        1            0
# 146          0             0            0        1            0
# 147          0             0            0        1            0
# 148          0             0            0        1            0
# 149          1             0            0        0            0
# 150          0             0            0        1            0
# 151          0             0            0        1            0
# 152          0             0            0        1            0
# 153          0             0            0        1            0
# 154          0             0            0        1            0
# 155          0             0            0        1            0
# 156          0             0            0        1            0
# 157          0             0            0        1            0
# 158          0             0            0        1            0
# 159          0             0            0        1            0
# 160          0             0            1        1            0
# 161          0             0            0        1            0
# 162          1             1            1        0            0
# 163          0             0            0        1            0
# 164          0             0            0        1            0
# 165          1             0            0        0            0
# 166          0             0            0        1            0
# 167          0             0            0        1            0
# 168          0             0            0        1            0
# 169          0             0            0        1            0
# 170          0             0            0        1            0
# 171          0             0            0        1            0
# 172          0             0            0        1            0
# 173          0             0            0        1            0
# 174          0             0            0        1            0
# 175          0             0            0        1            0
# 176          0             0            0        1            0
# 177          0             0            0        1            0
# 178          1             0            0        1            0
# 179          0             0            0        1            0
# 180          0             0            0        1            0
# 181          1             0            0        0            0
# 182          0             0            0        1            0
# 183          1             1            1        0            0
# 184          1             0            0        1            0
# 185          0             0            0        1            0
# 186          0             0            0        1            5
# 187          0             0            0        1            5
# 188          0             0            0        1            5
# 189          0             0            0        1            5
# 190          0             0            0        1            5
# 191          1             1            0        1            5
# 192          0             0            0        1            5
# 193          1             0            1        0            5
# 194          0             0            0        1            5
# 195          0             0            0        1            5
# 196          0             0            0        1            5
# 197          0             0            0        1            5
# 198          0             0            0        1            5
# 199          0             0            0        1            5
# 200          0             0            0        1           14
# 201          0             0            0        1           14
# 202          0             0            0        1           10
# 203          0             0            0        1           10
# 204          0             0            0        1           10
# 205          0             0            0        1           10
# 206          0             0            0        1           10
# 207          0             0            0        1           10
# 208          0             0            0        1           10
# 209          0             0            0        1           10
# 210          0             0            0        1           10
# 211          1             0            0        0           10
# 212          0             0            0        1           10
# 213          1             0            0        1           10
# 214          0             0            0        1           10
# 215          0             0            0        1           10
# 216          0             0            0        1           10
# 217          0             0            0        1           10
# 218          0             0            0        1           10
# 219          0             0            0        1           10
# 220          0             0            0        1           10
# 221          0             0            0        1            4
# 222          1             0            0        1            4
# 223          0             0            0        1            4
# 224          0             0            0        1            4
# 225          1             0            0        0            4
# 226          0             0            0        1            4
# 227          1             0            0        1            4
# 228          0             0            0        1            4
# 229          0             0            0        1            4
# 230          0             0            0        1            4
# 231          0             1            1        1            4
# 232          1             0            1        0            4
# 233          0             0            0        1            4
# 234          0             0            0        1            3
# 235          0             0            0        1            3
# 236          0             0            0        1            3
# 237          0             0            0        1            3
# 238          0             0            0        1            3
# 239          0             0            0        1            3
# 240          0             0            0        0            3
# 241          0             0            0        1            3
# 242          0             0            0        1            3
# 243          0             0            0        1            3
# 244          0             0            0        1            3
# 245          1             0            0        1            3
# 246          0             0            0        1            3
# 247          1             0            1        0            7
# 248          0             0            0        1            7
# 249          0             0            0        1            7
# 250          1             0            1        0            7
# 251          1             1            1        0            7
# 252          0             0            0        1            7
# 253          0             0            0        1            7
# 254          0             0            0        1           11
# 255          0             0            0        1            0
# 256          0             0            1        1            0
# 257          0             0            0        1            6
# 258          1             0            1        0            6
# 259          0             1            0        1            6
# 260          0             0            0        1            6
# 261          0             0            0        1            6
# 262          0             0            0        1            6
# 263          0             0            0        1            6
# 264          0             0            0        1            6
# 265          1             0            1        0            6
# 266          0             0            0        1            6
# 267          0             0            0        1            6
# 268          0             0            0        1            6
# 269          0             0            0        1            6
# 270          0             0            0        1            6
# 271          0             0            0        1            6
# 272          0             0            0        1            6
# 273          0             0            0        1            1
# 274          0             0            0        1            1
# 275          0             0            0        1            1
# 276          0             0            0        1            1
# 277          0             0            0        1            1
# 278          0             0            0        1            1
# 279          0             0            1        1            2
# 280          0             0            0        1            2
# 281          0             0            0        1            2
# 282          1             0            1        0            2
# 283          0             0            0        1            2
# 284          0             0            0        1            2
# 285          0             0            0        1            2
# 286          0             0            0        1            2
# 287          0             0            0        1            2
# 288          0             0            0        1            2
# 289          0             0            0        1            2
# 290          1             0            0        1            2
# 291          0             0            0        1            2
# 292          0             0            0        1            2
# 293          0             0            0        1            2
# 294          1             0            1        0            2
# 295          1             0            0        1            2
# 296          0             0            0        1            2
# 297          0             0            0        1            2
# 298          0             0            0        1            2
# 299          1             0            0        1            2
# 300          1             0            0        1            8
# 301          0             0            0        0            8
# 302          0             0            0        1            8
# 303          0             0            0        1            8
# 304          0             0            1        0            8
# 305          0             0            0        1            8
# 306          0             0            0        1            8
# 307          0             0            0        1            8
# 308          1             1            0        0            8
# 309          0             0            0        1            8
# 310          0             0            0        1            8
# 311          0             0            0        1            8
# 312          0             0            0        1            8
# 313          0             0            0        1            8
# 314          0             0            0        1            8
# 315          0             0            0        1            8
# 316          0             0            0        1            8
# 317          0             0            0        1            8
# 318          0             0            0        1            8
# 319          0             0            0        1            8
# 320          0             0            0        1            8
# 321          0             0            0        1            8
# 322          0             0            0        1            8
# 323          0             0            0        1            8
# 324          0             0            0        1            8
# 325          0             0            0        1            8
# 326          0             0            0        1            8
# 327          0             0            0        1            8
# 328          0             0            0        1           13
# 329          0             0            0        1           13
# 330          0             0            0        1           13
# 331          0             0            0        1           13
# 332          0             0            0        1           13
# 333          0             0            0        1           13
# 334          0             0            0        1           13
# 335          1             0            1        0            5
# 336          0             0            0        1            5
# 337          0             0            0        1            5
# 338          0             0            0        0            5
# 339          0             0            0        1           17
# 340          0             0            0        1           17
# 341          0             0            0        1           17
# 342          0             0            0        1           17
# 343          0             0            0        1           17
# 344          0             0            0        1           12
# 345          0             0            0        1           12
# 346          1             1            1        0            9
# 347          0             0            0        1           16
# 348          0             0            0        1           16
# 349          0             0            0        1           16
# 350          0             0            0        1           16
# 351          0             0            0        1            5
# 352          1             0            0        0            5
# 353          0             0            0        1            5
# 354          0             1            0        1            5
# 355          0             0            0        1            5
# 356          0             0            0        1            5
# 357          0             0            0        1            5
# 358          1             0            1        0            5
# 359          0             0            0        1            5
# 360          0             0            0        1            5
# 361          0             0            0        1            5
# 362          0             0            0        1            5
# 363          0             0            0        0            5
# 364          1             0            0        0            5
# 365          0             0            0        1            5
# 366          0             0            0        1            5
# 367          0             0            0        1            5
# 368          0             0            0        1            5
# 369          0             0            0        1            5
# 370          1             0            1        1            5
# 371          0             0            0        1            5
# 372          0             0            0        1            5
# 373          0             0            0        1            5
# 374          0             0            0        1            5
# 375          0             0            0        1            5
# 376          0             0            0        1            5
# 377          0             0            0        1            5
# 378          0             0            0        1            5
# 379          0             0            0        1            5
# 380          0             0            0        1            5
# 381          0             0            0        1            5
# 382          0             0            0        1            5
# 383          0             0            0        1            5
# 384          0             0            0        1           16
# 385          0             0            0        1           16
# 386          0             0            0        1           16
# 387          0             0            0        1           16
# 388          0             0            0        1           16
# 389          0             0            0        1           16
# 390          0             0            0        1           16
# 391          0             0            0        1           16
# 392          0             0            0        1           16
# 393          0             0            0        1           16
# 394          1             0            0        1           16
# 395          0             0            0        1           16
# 396          0             0            0        1           16
# 397          0             0            0        1           16
# 398          0             0            0        1           16
# 399          0             0            0        1           16
# 400          0             0            0        1           16
# 401          0             0            0        1           16
# 402          1             0            0        1           16

# %%
print(trans_res_venues.shape)
# Out:
# (403, 12)

# %% [markdown]
# ### Finding best k for cluster analysis

# %%
inertia = []

for i in range(1, 10): 
    kmeans = KMeans(n_clusters=i, random_state=0).fit(trans_res_venues) 
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 10), inertia, color ='g', linewidth ='3') 
plt.xlabel("Value of K") 
plt.ylabel("Sqaured Error (Cost)") 
plt.show()

# %% [markdown]
# ### The Squared error reduced significantly when k = 3

# %%
# set number of clusters
kclusters = 3

# %%
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(trans_res_venues)

# check cluster labels generated for each row in the dataframe
len(kmeans.labels_)
# Out:
# 403

# %%
res_cluster = res_venues.copy()
res_cluster.insert(0, 'Cluster Labels', kmeans.labels_)

res_cluster.head()
# Out:
#    Cluster Labels       Neighborhood                 Venue  \
# 0               2  100 McAllister St                Villon
# 1               1  100 McAllister St    The Flying Falafel
# 2               2  100 McAllister St  Morty's Delicatessen
# 3               0  100 McAllister St      Golden Era Vegan
# 4               1  100 McAllister St         Yemen Kitchen
#
#                    Venue id                 Venue Category  Venue Likes  \
# 0  59b759e1646e387b4245f12a              French Restaurant          119
# 1  54c42de4498ee52a43a5ee44       Mediterranean Restaurant          271
# 2  49d66c4ef964a520c95c1fe3            American Restaurant           36
# 3  547a3a09498edded45384099  Vegetarian / Vegan Restaurant           96
# 4  5633e4a5498e430fc92b4b53      Middle Eastern Restaurant           28
#
#    Venue photos count  Venue rating  Venue Tips Price Tier       Reservations  \
# 0                 135           8.8          14          3  No Data Available
# 1                 132           8.7          58          2                 No
# 2                  39           8.1          31          1                 No
# 3                 102           8.3          28          2  No Data Available
# 4                  39           8.3           9          2                 No
#
#              Outdoor               Wifi           Delivery              Music  \
# 0  No Data Available  No Data Available           Delivery  No Data Available
# 1  No Data Available  No Data Available           Delivery  No Data Available
# 2  No Data Available  No Data Available           Delivery  No Data Available
# 3  No Data Available  No Data Available  No Data Available  No Data Available
# 4  No Data Available  No Data Available           Take-out  No Data Available
#
#            Rest room       Private room        Wheel chair            Parking  \
# 0  No Data Available  No Data Available  No Data Available          Available
# 1  No Data Available  No Data Available  No Data Available  No Data Available
# 2  No Data Available  No Data Available  No Data Available  No Data Available
# 3  No Data Available  No Data Available  No Data Available  No Data Available
# 4  No Data Available  No Data Available  No Data Available  No Data Available
#
#                                         Institution   Latitude   Longitude
# 0  University of California Hastings College of Law  37.780989 -122.413846
# 1  University of California Hastings College of Law  37.780989 -122.413846
# 2  University of California Hastings College of Law  37.780989 -122.413846
# 3  University of California Hastings College of Law  37.780989 -122.413846
# 4  University of California Hastings College of Law  37.780989 -122.413846

# %% [markdown]
# ### Visualize the clusters

# %%
# create map
sf_location =  geocoder.geocode('San Francisco, CA, United States of America')
lat = sf_location[0]['geometry']['lat']
lng =  sf_location[0]['geometry']['lng']

# %%
map_clusters = folium.Map(location=[lat, lng], zoom_start=12, attr='<a href=/>No Link</a>')

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %%
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(res_cluster['Latitude'], res_cluster['Longitude'], res_cluster['Neighborhood'], res_cluster['Cluster Labels']):
    label = folium.Popup(html=str(poi) + ' Cluster ' + str(cluster))
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Analysing the clusters

# %% [markdown]
# ### Cluster 1:

# %%
res_cluster.loc[res_cluster['Cluster Labels'] == 0].head()
# Out:
#    Cluster Labels       Neighborhood              Venue  \
# 3               0  100 McAllister St   Golden Era Vegan
# 5               0  100 McAllister St           Birdsong
# 6               0  100 McAllister St  Tú Lan Restaurant
# 8               0  100 McAllister St           Mộng Thu
# 9               0  100 McAllister St     Elephant Sushi
#
#                    Venue id                 Venue Category  Venue Likes  \
# 3  547a3a09498edded45384099  Vegetarian / Vegan Restaurant           96
# 5  5ae925e7c0f163002cc57349                     Restaurant           61
# 6  41799f00f964a520c11d1fe3          Vietnamese Restaurant          316
# 8  4cdf14a1ffcf3704523e1782          Vietnamese Restaurant           18
# 9  530eab1b498e43184817a4fc               Sushi Restaurant           13
#
#    Venue photos count  Venue rating  Venue Tips Price Tier       Reservations  \
# 3                 102           8.3          28          2  No Data Available
# 5                  92           9.1           8          2                Yes
# 6                 351           8.5         144          1  No Data Available
# 8                  37           7.9           7          2  No Data Available
# 9                  30           7.7           1          2                 No
#
#              Outdoor               Wifi           Delivery              Music  \
# 3  No Data Available  No Data Available  No Data Available  No Data Available
# 5  No Data Available                 No        No Delivery                Yes
# 6  No Data Available  No Data Available           Take-out  No Data Available
# 8  No Data Available  No Data Available           Delivery  No Data Available
# 9  No Data Available  No Data Available           Delivery  No Data Available
#
#            Rest room       Private room        Wheel chair            Parking  \
# 3  No Data Available  No Data Available  No Data Available  No Data Available
# 5                Yes                Yes  No Data Available  No Data Available
# 6  No Data Available  No Data Available  No Data Available  No Data Available
# 8  No Data Available  No Data Available  No Data Available  No Data Available
# 9  No Data Available  No Data Available  No Data Available  No Data Available
#
#                                         Institution   Latitude   Longitude
# 3  University of California Hastings College of Law  37.780989 -122.413846
# 5  University of California Hastings College of Law  37.780989 -122.413846
# 6  University of California Hastings College of Law  37.780989 -122.413846
# 8  University of California Hastings College of Law  37.780989 -122.413846
# 9  University of California Hastings College of Law  37.780989 -122.413846

# %% [markdown]
# ### Cluster 2:

# %%
res_cluster.loc[res_cluster['Cluster Labels'] == 1].head()
# Out:
#     Cluster Labels       Neighborhood                  Venue  \
# 1                1  100 McAllister St     The Flying Falafel
# 4                1  100 McAllister St          Yemen Kitchen
# 15               1  100 McAllister St              Gyro King
# 20               1  100 McAllister St          El Castillito
# 25               1  100 McAllister St  Jin Mi Korean Cuisine
#
#                     Venue id             Venue Category  Venue Likes  \
# 1   54c42de4498ee52a43a5ee44   Mediterranean Restaurant          271
# 4   5633e4a5498e430fc92b4b53  Middle Eastern Restaurant           28
# 15  44e36f32f964a52041371fe3   Mediterranean Restaurant           46
# 20  51b28827498ef0351235c618         Mexican Restaurant           10
# 25  52c1ec13498e768ed96c0fdf          Korean Restaurant           73
#
#     Venue photos count  Venue rating  Venue Tips Price Tier Reservations  \
# 1                  132           8.7          58          2           No
# 4                   39           8.3           9          2           No
# 15                  64           7.5          38          2           No
# 20                   6           7.1           2          1           No
# 25                  85           7.1          25          1           No
#
#               Outdoor               Wifi  Delivery              Music  \
# 1   No Data Available  No Data Available  Delivery  No Data Available
# 4   No Data Available  No Data Available  Take-out  No Data Available
# 15  No Data Available  No Data Available  Delivery  No Data Available
# 20  No Data Available  No Data Available  Delivery  No Data Available
# 25  No Data Available  No Data Available  Take-out  No Data Available
#
#             Rest room       Private room        Wheel chair  \
# 1   No Data Available  No Data Available  No Data Available
# 4   No Data Available  No Data Available  No Data Available
# 15  No Data Available  No Data Available  No Data Available
# 20                Yes  No Data Available                Yes
# 25                Yes  No Data Available                Yes
#
#               Parking                                       Institution  \
# 1   No Data Available  University of California Hastings College of Law
# 4   No Data Available  University of California Hastings College of Law
# 15  No Data Available  University of California Hastings College of Law
# 20  No Data Available  University of California Hastings College of Law
# 25  No Data Available  University of California Hastings College of Law
#
#      Latitude   Longitude
# 1   37.780989 -122.413846
# 4   37.780989 -122.413846
# 15  37.780989 -122.413846
# 20  37.780989 -122.413846
# 25  37.780989 -122.413846

# %% [markdown]
# ### Cluster 3:

# %%
res_cluster.loc[res_cluster['Cluster Labels'] == 2].head()
# Out:
#     Cluster Labels       Neighborhood                   Venue  \
# 0                2  100 McAllister St                  Villon
# 2                2  100 McAllister St    Morty's Delicatessen
# 7                2  100 McAllister St    Sunday at the Museum
# 12               2  100 McAllister St  Tadu Ethiopian Kitchen
# 18               2  100 McAllister St             homeskillet
#
#                     Venue id        Venue Category  Venue Likes  \
# 0   59b759e1646e387b4245f12a     French Restaurant          119
# 2   49d66c4ef964a520c95c1fe3   American Restaurant           36
# 7   5ac91da5c5309357e35b5e75      Asian Restaurant           30
# 12  54c16037498e2e5544db41d1  Ethiopian Restaurant           94
# 18  5351e136498e38b9d504db86   American Restaurant          151
#
#     Venue photos count  Venue rating  Venue Tips Price Tier  \
# 0                  135           8.8          14          3
# 2                   39           8.1          31          1
# 7                   41           7.7           5          2
# 12                  69           8.4          22          2
# 18                 118           7.6          34          2
#
#          Reservations            Outdoor               Wifi     Delivery  \
# 0   No Data Available  No Data Available  No Data Available     Delivery
# 2                  No  No Data Available  No Data Available     Delivery
# 7                  No  No Data Available  No Data Available     Delivery
# 12                 No  No Data Available  No Data Available     Delivery
# 18                 No  No Data Available                Yes  No Delivery
#
#                 Music          Rest room       Private room  \
# 0   No Data Available  No Data Available  No Data Available
# 2   No Data Available  No Data Available  No Data Available
# 7   No Data Available  No Data Available  No Data Available
# 12  No Data Available  No Data Available  No Data Available
# 18  No Data Available  No Data Available  No Data Available
#
#           Wheel chair            Parking  \
# 0   No Data Available          Available
# 2   No Data Available  No Data Available
# 7   No Data Available  No Data Available
# 12  No Data Available  No Data Available
# 18  No Data Available  No Data Available
#
#                                          Institution   Latitude   Longitude
# 0   University of California Hastings College of Law  37.780989 -122.413846
# 2   University of California Hastings College of Law  37.780989 -122.413846
# 7   University of California Hastings College of Law  37.780989 -122.413846
# 12  University of California Hastings College of Law  37.780989 -122.413846
# 18  University of California Hastings College of Law  37.780989 -122.413846
